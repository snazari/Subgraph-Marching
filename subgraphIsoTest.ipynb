# %%
from sgm_functions import *
from DirectedWeightedGraph import DWGraph
import graph_tool.draw.gtk_draw as gt_draw
import pandas as pd
from graph_tool.all import *

# %%
g = DWGraph.from_file_edge_list("art_ex1.graph",is_weighted=False,make_undirected=True,skip_first_line=False)
g.add_labels_from_file("art_ex1.labels")

g0 = DWGraph.from_file_edge_list("art_template1.graph",is_weighted=False,make_undirected=True,skip_first_line=False)
g0.add_labels_from_file("art_template1.labels")

# %%
g = add_original_enumeration(g)
g0 = add_original_enumeration(g0)
prop_label_g = g.vp['label']
prop_label_g0 = g0.vp['label']
prop_g_v = vp_map(g, 'nValue', 'int')

# %%
graph_draw(g)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f6019400898, at 0x7f6019400438>

# %%
for i, v in enumerate(g.vertices()):
    prop_g_v[v] = prop_label_g[v]

prop_g0_v = vp_map(g0, 'nValue', 'int')
for i, v in enumerate(g0.vertices()):
    prop_g0_v[v] = prop_label_g0[v]

prop_g = ep_map(g, 'eValue', 'int')
for e in g.edges():
    prop_g[e] = 1

prop_g0 = ep_map(g0, 'eValue', 'int')
for e in g0.edges():
    prop_g0[e] = 1

# %%
graph_draw(g, vertex_text=g.vp['old'], vertex_font_size=18)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f6019400898, at 0x7f60193a6048>

# %%
graph_draw(g, vertex_text=g.vp['label'], vertex_font_size=18)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f6019400898, at 0x7f6019400978>

# %%
graph_draw(g0, vertex_text=g0.vp['old'], vertex_font_size=18)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f60193e9e48, at 0x7f60193a4d68>

# %%
graph_draw(g0, vertex_text=g0.vp['label'], vertex_font_size=18)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f60193e9e48, at 0x7f60193a4ac8>

# %%
left=reduce_space(g0, g, 0, 0, method='MDST')
# Out:
# Hashing...
# Done at 0.003482818603515625
# Calculating MDST
# Printing t_graph
# Directed
# 0  :  {'old': 1, 'label': 0, 'original': 0, 'nValue': 0, 'MDST_v_weight': 0.2727272727272727, 'fromANode': 0}
# 1  :  {'old': 2, 'label': 1, 'original': 1, 'nValue': 1, 'MDST_v_weight': 0.36363636363636365, 'fromANode': 1}
# 2  :  {'old': 3, 'label': 2, 'original': 2, 'nValue': 2, 'MDST_v_weight': 0.36363636363636365, 'fromANode': 2}
# (0, 1)  :  {'w': 0.0, 'eValue': 1, 'MDST_e_weight': 2.0, 'fromAEdge': (0, 1)}
# (0, 2)  :  {'w': 0.0, 'eValue': 1, 'MDST_e_weight': 2.0, 'fromAEdge': (0, 2)}
# t_score 0.6694214876033058
# Done at 0.03269624710083008
# Matching
# Printing MDST Graph
# 0
# Directed
# 0  :  {'old': 1, 'label': 0, 'original': 0, 'nValue': 0, 'MDST_v_weight': 0.2727272727272727, 'fromANode': 0}
# 1  :  {'old': 2, 'label': 1, 'original': 1, 'nValue': 1, 'MDST_v_weight': 0.36363636363636365, 'fromANode': 1}
# ...

# %%
left
# Out:
# ([11, 10],
#  [13, 12],
#  [{(1, 2): (2, 3), (3, 1): (4, 2), 1: 2, 2: 3, 3: 4},
#   {(1, 2): (2, 3), (3, 1): (1, 2), 1: 2, 2: 3, 3: 1},
#   {(1, 2): (5, 10), (2, 3): (10, 4), (3, 1): (4, 5), 1: 5, 2: 10, 3: 4},
#   {(1, 2): (5, 10), (3, 1): (6, 5), 1: 5, 2: 10, 3: 6},
#   {(1, 2): (5, 3), (3, 1): (4, 5), 1: 5, 2: 3, 3: 4},
#   {(1, 2): (5, 3), (3, 1): (6, 5), 1: 5, 2: 3, 3: 6},
#   {(1, 2): (8, 7), (3, 1): (9, 8), 1: 8, 2: 7, 3: 9}],
#  [5, 5, 6, 5, 5, 5, 5])
